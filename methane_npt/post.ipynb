# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
energy = np.loadtxt('energy.xvg',skiprows=24)

plt.plot(energy[:,0], energy[:,1])
plt.axhline(y=np.mean(energy[:,1]), color="k", linestyle="--", linewidth=1.5)
plt.xlabel('Time (ps)')
plt.ylabel('Energy (kJ/mol)')
# Out:
# Text(0, 0.5, 'Energy (kJ/mol)')

# %%
temperature = np.loadtxt('temperature.xvg',skiprows=24)

plt.plot(temperature[:,0], temperature[:,1])
plt.axhline(y=np.mean(temperature[:,1]), color="k", linestyle="--", linewidth=1.5)
plt.xlabel('Time (ps)')
plt.ylabel('Temperature (K)')
# Out:
# Text(0, 0.5, 'Temperature (K)')

# %%
pressure = np.loadtxt('pressure.xvg',skiprows=24)

plt.plot(pressure[:,0], pressure[:,1])
plt.axhline(y=np.mean(pressure[:,1]), color="k", linestyle="--", linewidth=1.5)
plt.xlabel('Time (ps)')
plt.ylabel('Pressure (bar)')
# Out:
# Text(0, 0.5, 'Pressure (bar)')

# %%
density = np.loadtxt('density.xvg',skiprows=24)

plt.plot(density[:,0], density[:,1])
plt.axhline(y=np.mean(density[:,1]), color="k", linestyle="--", linewidth=1.5)
plt.xlabel('Time (ps)')
plt.ylabel('Density (kg/m3)')
# Out:
# Text(0, 0.5, 'Density (kg/m3)')
